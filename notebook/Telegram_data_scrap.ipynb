# %% [markdown]
# ### Task 1: Ethiomart Data Ingestion and  Data Preprocessing

# %%
import os
import sys
import pandas as pd
import asyncio
# Get the current working directory
current_dir = os.getcwd()

# Append the parent directory to sys.path
parent_dir = os.path.dirname(current_dir)
sys.path.append(parent_dir)

# ignore warrnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Import the TelegramScraper class from the file where it's defined
from scripts.telegram_scraper import TelegramScraper
from scripts.text_preprocessor import  AmharicTextPreprocessor

# %% [markdown]
# ### Telegram Message Scraping

# %%
# List of channels to scrape
channels = ['modernshoppingcenter']

# Initialize the TelegramScraper instance
scraper = TelegramScraper()

# %%
# Define a function to run the asynchronous methods in the notebook
async def run_scraper():
    await scraper.connect()  # Connect to Telegram
    await scraper.fetch_messages(channels, message_limit=5000, output_file='../data/telegram_messages.csv')  # Fetch messages
    await scraper.disconnect()  # Disconnect from Telegram

# %%
# Run the scraper asynchronously in the notebook
await run_scraper()
# Out:
# Connected to Telegram
# Joining and fetching messages from modernshoppingcenter...
# Saving message 5382 from modernshoppingcenter
# Saving message 5381 from modernshoppingcenter
# Saving message 5380 from modernshoppingcenter
# Saving message 5379 from modernshoppingcenter
# Saving message 5378 from modernshoppingcenter
# Saving message 5377 from modernshoppingcenter
# Saving message 5376 from modernshoppingcenter
# Saving message 5375 from modernshoppingcenter
# Saving message 5374 from modernshoppingcenter
# Saving message 5373 from modernshoppingcenter
# Saving message 5372 from modernshoppingcenter
# Saving message 5371 from modernshoppingcenter
# Saving message 5370 from modernshoppingcenter
# Saving message 5369 from modernshoppingcenter
# Saving message 5368 from modernshoppingcenter
# Saving message 5367 from modernshoppingcenter
# Saving message 5366 from modernshoppingcenter
# Saving message 5365 from modernshoppingcenter
# Saving message 5364 from modernshoppingcenter
# Saving message 5363 from modernshoppingcenter
# Saving message 5362 from modernshoppingcenter
# Saving message 5361 from modernshoppingcenter
# Saving message 5360 from modernshoppingcenter
# Saving message 5359 from modernshoppingcenter
# Saving message 5358 from modernshoppingcenter
# Saving message 5357 from modernshoppingcenter
# Saving message 5356 from modernshoppingcenter
# Saving message 5355 from modernshoppingcenter
# Saving message 5354 from modernshoppingcenter
# Saving message 5353 from modernshoppingcenter
# Saving message 5352 from modernshoppingcenter
# Saving message 5351 from modernshoppingcenter
# Saving message 5350 from modernshoppingcenter
# Saving message 5349 from modernshoppingcenter
# Saving message 5348 from modernshoppingcenter
# Saving message 5347 from modernshoppingcenter
# Saving message 5346 from modernshoppingcenter
# Saving message 5345 from modernshoppingcenter
# Saving message 5344 from modernshoppingcenter
# Saving message 5343 from modernshoppingcenter
# Saving message 5342 from modernshoppingcenter
# Saving message 5341 from modernshoppingcenter
# Saving message 5340 from modernshoppingcenter
# Saving message 5339 from modernshoppingcenter
# Saving message 5338 from modernshoppingcenter
# Saving message 5337 from modernshoppingcenter
# Saving message 5336 from modernshoppingcenter
# Saving message 5335 from modernshoppingcenter
# Saving message 5334 from modernshoppingcenter
# Saving message 5333 from modernshoppingcenter
# Saving message 5332 from modernshoppingcenter
# Saving message 5331 from modernshoppingcenter
# Saving message 5330 from modernshoppingcenter
# Saving message 5329 from modernshoppingcenter
# Saving message 5328 from modernshoppingcenter
# Saving message 5327 from modernshoppingcenter
# Saving message 5326 from modernshoppingcenter
# Saving message 5325 from modernshoppingcenter
# Saving message 5324 from modernshoppingcenter
# Saving message 5323 from modernshoppingcenter
# Saving message 5322 from modernshoppingcenter
# Saving message 5321 from modernshoppingcenter
# Saving message 5320 from modernshoppingcenter
# Saving message 5319 from modernshoppingcenter
# Saving message 5318 from modernshoppingcenter
# Saving message 5317 from modernshoppingcenter
# Saving message 5316 from modernshoppingcenter
# Saving message 5315 from modernshoppingcenter
# Saving message 5314 from modernshoppingcenter
# Saving message 5313 from modernshoppingcenter
# Saving message 5312 from modernshoppingcenter
# Saving message 5311 from modernshoppingcenter
# Saving message 5310 from modernshoppingcenter
# Saving message 5309 from modernshoppingcenter
# Saving message 5308 from modernshoppingcenter
# Saving message 5307 from modernshoppingcenter
# Saving message 5306 from modernshoppingcenter
# Saving message 5305 from modernshoppingcenter
# Saving message 5304 from modernshoppingcenter
# Saving message 5303 from modernshoppingcenter
# Saving message 5302 from modernshoppingcenter
# Saving message 5301 from modernshoppingcenter
# Saving message 5300 from modernshoppingcenter
# Saving message 5299 from modernshoppingcenter
# Saving message 5298 from modernshoppingcenter
# Saving message 5297 from modernshoppingcenter
# Saving message 5296 from modernshoppingcenter
# Saving message 5295 from modernshoppingcenter
# Saving message 5294 from modernshoppingcenter
# Saving message 5293 from modernshoppingcenter
# Saving message 5292 from modernshoppingcenter
# Saving message 5291 from modernshoppingcenter
# Saving message 5290 from modernshoppingcenter
# Saving message 5289 from modernshoppingcenter
# Saving message 5288 from modernshoppingcenter
# Saving message 5287 from modernshoppingcenter
# Saving message 5286 from modernshoppingcenter
# Saving message 5285 from modernshoppingcenter
# Saving message 5284 from modernshoppingcenter
# Saving message 5283 from modernshoppingcenter
# Saving message 5282 from modernshoppingcenter
# Saving message 5281 from modernshoppingcenter
# Saving message 5280 from modernshoppingcenter
# Saving message 5279 from modernshoppingcenter
# Saving message 5278 from modernshoppingcenter
# Saving message 5277 from modernshoppingcenter
# Saving message 5276 from modernshoppingcenter
# Saving message 5275 from modernshoppingcenter
# Saving message 5274 from modernshoppingcenter
# Saving message 5273 from modernshoppingcenter
# Saving message 5272 from modernshoppingcenter
# Saving message 5271 from modernshoppingcenter
# Saving message 5270 from modernshoppingcenter
# Saving message 5269 from modernshoppingcenter
# Saving message 5268 from modernshoppingcenter
# Saving message 5267 from modernshoppingcenter
# Saving message 5266 from modernshoppingcenter
# Saving message 5265 from modernshoppingcenter
# Saving message 5264 from modernshoppingcenter
# Saving message 5263 from modernshoppingcenter
# Saving message 5262 from modernshoppingcenter
# Saving message 5261 from modernshoppingcenter
# Saving message 5260 from modernshoppingcenter
# Saving message 5259 from modernshoppingcenter
# Saving message 5258 from modernshoppingcenter
# Saving message 5257 from modernshoppingcenter
# Saving message 5256 from modernshoppingcenter
# Saving message 5255 from modernshoppingcenter
# Saving message 5254 from modernshoppingcenter
# Saving message 5251 from modernshoppingcenter
# Saving message 5250 from modernshoppingcenter
# Saving message 5249 from modernshoppingcenter
# Saving message 5248 from modernshoppingcenter
# Saving message 5247 from modernshoppingcenter
# Saving message 5246 from modernshoppingcenter
# Saving message 5245 from modernshoppingcenter
# Saving message 5244 from modernshoppingcenter
# Saving message 5243 from modernshoppingcenter
# Saving message 5242 from modernshoppingcenter
# Saving message 5241 from modernshoppingcenter
# Saving message 5240 from modernshoppingcenter
# Saving message 5239 from modernshoppingcenter
# Saving message 5238 from modernshoppingcenter
# Saving message 5237 from modernshoppingcenter
# Saving message 5236 from modernshoppingcenter
# Saving message 5235 from modernshoppingcenter
# Saving message 5234 from modernshoppingcenter
# Saving message 5233 from modernshoppingcenter
# Saving message 5232 from modernshoppingcenter
# Saving message 5231 from modernshoppingcenter
# Saving message 5226 from modernshoppingcenter
# Saving message 5225 from modernshoppingcenter
# Saving message 5224 from modernshoppingcenter
# Saving message 5223 from modernshoppingcenter
# Saving message 5222 from modernshoppingcenter
# Saving message 5221 from modernshoppingcenter
# Saving message 5220 from modernshoppingcenter
# Saving message 5219 from modernshoppingcenter
# Saving message 5218 from modernshoppingcenter
# Saving message 5217 from modernshoppingcenter
# Saving message 5215 from modernshoppingcenter
# Saving message 5214 from modernshoppingcenter
# Saving message 5213 from modernshoppingcenter
# Saving message 5212 from modernshoppingcenter
# Saving message 5211 from modernshoppingcenter
# Saving message 5210 from modernshoppingcenter
# Saving message 5209 from modernshoppingcenter
# Saving message 5208 from modernshoppingcenter
# Saving message 5207 from modernshoppingcenter
# Saving message 5206 from modernshoppingcenter
# Saving message 5205 from modernshoppingcenter
# Saving message 5204 from modernshoppingcenter
# Saving message 5203 from modernshoppingcenter
# Saving message 5202 from modernshoppingcenter
# Saving message 5201 from modernshoppingcenter
# Saving message 5200 from modernshoppingcenter
# Saving message 5199 from modernshoppingcenter
# Saving message 5198 from modernshoppingcenter
# Saving message 5197 from modernshoppingcenter
# Saving message 5196 from modernshoppingcenter
# Saving message 5195 from modernshoppingcenter
# Saving message 5194 from modernshoppingcenter
# Saving message 5193 from modernshoppingcenter
# Saving message 5192 from modernshoppingcenter
# Saving message 5191 from modernshoppingcenter
# Saving message 5190 from modernshoppingcenter
# Saving message 5189 from modernshoppingcenter
# Saving message 5188 from modernshoppingcenter
# Saving message 5185 from modernshoppingcenter
# Saving message 5184 from modernshoppingcenter
# Saving message 5183 from modernshoppingcenter
# Saving message 5182 from modernshoppingcenter
# Saving message 5181 from modernshoppingcenter
# Saving message 5180 from modernshoppingcenter
# Saving message 5179 from modernshoppingcenter
# Saving message 5178 from modernshoppingcenter
# Saving message 5177 from modernshoppingcenter
# Saving message 5176 from modernshoppingcenter
# Saving message 5175 from modernshoppingcenter
# Saving message 5174 from modernshoppingcenter
# Saving message 5173 from modernshoppingcenter
# Saving message 5172 from modernshoppingcenter
# Saving message 5171 from modernshoppingcenter
# Saving message 5170 from modernshoppingcenter
# Saving message 5169 from modernshoppingcenter
# Saving message 5168 from modernshoppingcenter
# Saving message 5167 from modernshoppingcenter
# Saving message 5166 from modernshoppingcenter
# Saving message 5165 from modernshoppingcenter
# Saving message 5164 from modernshoppingcenter
# Saving message 5163 from modernshoppingcenter
# Saving message 5162 from modernshoppingcenter
# Saving message 5161 from modernshoppingcenter
# Saving message 5160 from modernshoppingcenter
# Saving message 5159 from modernshoppingcenter
# Saving message 5158 from modernshoppingcenter
# Saving message 5157 from modernshoppingcenter
# Saving message 5156 from modernshoppingcenter
# Saving message 5155 from modernshoppingcenter
# Saving message 5154 from modernshoppingcenter
# Saving message 5153 from modernshoppingcenter
# Saving message 5152 from modernshoppingcenter
# Saving message 5151 from modernshoppingcenter
# Saving message 5150 from modernshoppingcenter
# Saving message 5149 from modernshoppingcenter
# Saving message 5148 from modernshoppingcenter
# Saving message 5147 from modernshoppingcenter
# Saving message 5146 from modernshoppingcenter
# Saving message 5145 from modernshoppingcenter
# Saving message 5144 from modernshoppingcenter
# Saving message 5143 from modernshoppingcenter
# Saving message 5142 from modernshoppingcenter
# Saving message 5141 from modernshoppingcenter
# Saving message 5140 from modernshoppingcenter
# Saving message 5139 from modernshoppingcenter
# Saving message 5138 from modernshoppingcenter
# Saving message 5137 from modernshoppingcenter
# Saving message 5136 from modernshoppingcenter
# Saving message 5135 from modernshoppingcenter
# Saving message 5134 from modernshoppingcenter
# Saving message 5133 from modernshoppingcenter
# Saving message 5132 from modernshoppingcenter
# Saving message 5131 from modernshoppingcenter
# Saving message 5130 from modernshoppingcenter
# Saving message 5129 from modernshoppingcenter
# Saving message 5128 from modernshoppingcenter
# Saving message 5127 from modernshoppingcenter
# Saving message 5126 from modernshoppingcenter
# Saving message 5125 from modernshoppingcenter
# Saving message 5124 from modernshoppingcenter
# Saving message 5123 from modernshoppingcenter
# Saving message 5122 from modernshoppingcenter
# Saving message 5121 from modernshoppingcenter
# Saving message 5120 from modernshoppingcenter
# Saving message 5119 from modernshoppingcenter
# Saving message 5118 from modernshoppingcenter
# Saving message 5117 from modernshoppingcenter
# Saving message 5116 from modernshoppingcenter
# Saving message 5115 from modernshoppingcenter
# Saving message 5114 from modernshoppingcenter
# Saving message 5113 from modernshoppingcenter
# Saving message 5112 from modernshoppingcenter
# Saving message 5111 from modernshoppingcenter
# Saving message 5110 from modernshoppingcenter
# Saving message 5109 from modernshoppingcenter
# Saving message 5108 from modernshoppingcenter
# Saving message 5106 from modernshoppingcenter
# Saving message 5105 from modernshoppingcenter
# Saving message 5104 from modernshoppingcenter
# Saving message 5103 from modernshoppingcenter
# Saving message 5102 from modernshoppingcenter
# Saving message 5101 from modernshoppingcenter
# Saving message 5100 from modernshoppingcenter
# Saving message 5096 from modernshoppingcenter
# Saving message 5095 from modernshoppingcenter
# Saving message 5094 from modernshoppingcenter
# Saving message 5093 from modernshoppingcenter
# Saving message 5092 from modernshoppingcenter
# Saving message 5091 from modernshoppingcenter
# Saving message 5090 from modernshoppingcenter
# Saving message 5089 from modernshoppingcenter
# Saving message 5088 from modernshoppingcenter
# Saving message 5084 from modernshoppingcenter
# Saving message 5083 from modernshoppingcenter
# Saving message 5082 from modernshoppingcenter
# Saving message 5081 from modernshoppingcenter
# Saving message 5080 from modernshoppingcenter
# Saving message 5079 from modernshoppingcenter
# Saving message 5078 from modernshoppingcenter
# Saving message 5077 from modernshoppingcenter
# Saving message 5076 from modernshoppingcenter
# Saving message 5075 from modernshoppingcenter
# Saving message 5074 from modernshoppingcenter
# Saving message 5073 from modernshoppingcenter
# Saving message 5067 from modernshoppingcenter
# Saving message 5066 from modernshoppingcenter
# Saving message 5065 from modernshoppingcenter
# Saving message 5062 from modernshoppingcenter
# Saving message 5061 from modernshoppingcenter
# Saving message 5060 from modernshoppingcenter
# Saving message 5059 from modernshoppingcenter
# Saving message 5058 from modernshoppingcenter
# Saving message 5057 from modernshoppingcenter
# Saving message 5056 from modernshoppingcenter
# Saving message 5055 from modernshoppingcenter
# Saving message 5054 from modernshoppingcenter
# Saving message 5053 from modernshoppingcenter
# Saving message 5052 from modernshoppingcenter
# Saving message 5051 from modernshoppingcenter
# Saving message 5050 from modernshoppingcenter
# Saving message 5049 from modernshoppingcenter
# Saving message 5048 from modernshoppingcenter
# Saving message 5047 from modernshoppingcenter
# Saving message 5045 from modernshoppingcenter
# Saving message 5044 from modernshoppingcenter
# Saving message 5043 from modernshoppingcenter
# Saving message 5042 from modernshoppingcenter
# Saving message 5041 from modernshoppingcenter
# Saving message 5040 from modernshoppingcenter
# Saving message 5039 from modernshoppingcenter
# Saving message 5038 from modernshoppingcenter
# Saving message 5037 from modernshoppingcenter
# Saving message 5036 from modernshoppingcenter
# Saving message 5035 from modernshoppingcenter
# Saving message 5034 from modernshoppingcenter
# Saving message 5033 from modernshoppingcenter
# Saving message 5031 from modernshoppingcenter
# Saving message 5030 from modernshoppingcenter
# Saving message 5029 from modernshoppingcenter
# Saving message 5028 from modernshoppingcenter
# Saving message 5027 from modernshoppingcenter
# Saving message 5026 from modernshoppingcenter
# Saving message 5025 from modernshoppingcenter
# Saving message 5024 from modernshoppingcenter
# Saving message 5023 from modernshoppingcenter
# Saving message 5022 from modernshoppingcenter
# Saving message 5021 from modernshoppingcenter
# Saving message 5020 from modernshoppingcenter
# Saving message 5019 from modernshoppingcenter
# Saving message 5018 from modernshoppingcenter
# Saving message 5017 from modernshoppingcenter
# Saving message 5016 from modernshoppingcenter
# Saving message 5015 from modernshoppingcenter
# Saving message 5014 from modernshoppingcenter
# Saving message 5013 from modernshoppingcenter
# Saving message 5012 from modernshoppingcenter
# Saving message 5011 from modernshoppingcenter
# Saving message 5009 from modernshoppingcenter
# Saving message 5008 from modernshoppingcenter
# Saving message 5007 from modernshoppingcenter
# Saving message 5006 from modernshoppingcenter
# Saving message 5005 from modernshoppingcenter
# Saving message 5004 from modernshoppingcenter
# Saving message 5003 from modernshoppingcenter
# Saving message 5002 from modernshoppingcenter
# Saving message 5001 from modernshoppingcenter
# Saving message 5000 from modernshoppingcenter
# Saving message 4999 from modernshoppingcenter
# Saving message 4998 from modernshoppingcenter
# Saving message 4997 from modernshoppingcenter
# Saving message 4996 from modernshoppingcenter
# Saving message 4995 from modernshoppingcenter
# Saving message 4994 from modernshoppingcenter
# Saving message 4993 from modernshoppingcenter
# Saving message 4992 from modernshoppingcenter
# Saving message 4991 from modernshoppingcenter
# Saving message 4990 from modernshoppingcenter
# Saving message 4989 from modernshoppingcenter
# Saving message 4988 from modernshoppingcenter
# Saving message 4987 from modernshoppingcenter
# Saving message 4986 from modernshoppingcenter
# Saving message 4985 from modernshoppingcenter
# Saving message 4984 from modernshoppingcenter
# Saving message 4983 from modernshoppingcenter
# Saving message 4982 from modernshoppingcenter
# Saving message 4981 from modernshoppingcenter
# Saving message 4980 from modernshoppingcenter
# Saving message 4979 from modernshoppingcenter
# Saving message 4978 from modernshoppingcenter
# Saving message 4977 from modernshoppingcenter
# Saving message 4976 from modernshoppingcenter
# Saving message 4975 from modernshoppingcenter
# Saving message 4974 from modernshoppingcenter
# Saving message 4973 from modernshoppingcenter
# Saving message 4972 from modernshoppingcenter
# Saving message 4971 from modernshoppingcenter
# Saving message 4970 from modernshoppingcenter
# Saving message 4969 from modernshoppingcenter
# Saving message 4968 from modernshoppingcenter
# Saving message 4967 from modernshoppingcenter
# Saving message 4960 from modernshoppingcenter
# Saving message 4959 from modernshoppingcenter
# Saving message 4958 from modernshoppingcenter
# Saving message 4957 from modernshoppingcenter
# Saving message 4956 from modernshoppingcenter
# Saving message 4955 from modernshoppingcenter
# Saving message 4954 from modernshoppingcenter
# Saving message 4953 from modernshoppingcenter
# Saving message 4952 from modernshoppingcenter
# Saving message 4951 from modernshoppingcenter
# Saving message 4950 from modernshoppingcenter
# Saving message 4949 from modernshoppingcenter
# Saving message 4948 from modernshoppingcenter
# Saving message 4947 from modernshoppingcenter
# Saving message 4946 from modernshoppingcenter
# Saving message 4945 from modernshoppingcenter
# Saving message 4944 from modernshoppingcenter
# Saving message 4943 from modernshoppingcenter
# Saving message 4942 from modernshoppingcenter
# Saving message 4941 from modernshoppingcenter
# Saving message 4940 from modernshoppingcenter
# Saving message 4938 from modernshoppingcenter
# Saving message 4937 from modernshoppingcenter
# Saving message 4936 from modernshoppingcenter
# Saving message 4934 from modernshoppingcenter
# Saving message 4933 from modernshoppingcenter
# Saving message 4932 from modernshoppingcenter
# Saving message 4931 from modernshoppingcenter
# Saving message 4930 from modernshoppingcenter
# Saving message 4929 from modernshoppingcenter
# Saving message 4928 from modernshoppingcenter
# Saving message 4927 from modernshoppingcenter
# Saving message 4926 from modernshoppingcenter
# Saving message 4925 from modernshoppingcenter
# Saving message 4924 from modernshoppingcenter
# Saving message 4923 from modernshoppingcenter
# Saving message 4922 from modernshoppingcenter
# Saving message 4921 from modernshoppingcenter
# Saving message 4920 from modernshoppingcenter
# Saving message 4919 from modernshoppingcenter
# Saving message 4918 from modernshoppingcenter
# Saving message 4917 from modernshoppingcenter
# Saving message 4916 from modernshoppingcenter
# Saving message 4915 from modernshoppingcenter
# Saving message 4914 from modernshoppingcenter
# Saving message 4913 from modernshoppingcenter
# Saving message 4912 from modernshoppingcenter
# Saving message 4911 from modernshoppingcenter
# Saving message 4910 from modernshoppingcenter
# Saving message 4909 from modernshoppingcenter
# Saving message 4908 from modernshoppingcenter
# Saving message 4907 from modernshoppingcenter
# Saving message 4906 from modernshoppingcenter
# Saving message 4905 from modernshoppingcenter
# Saving message 4904 from modernshoppingcenter
# Saving message 4903 from modernshoppingcenter
# Saving message 4902 from modernshoppingcenter
# Saving message 4901 from modernshoppingcenter
# Saving message 4900 from modernshoppingcenter
# Saving message 4899 from modernshoppingcenter
# Saving message 4898 from modernshoppingcenter
# Saving message 4897 from modernshoppingcenter
# Saving message 4896 from modernshoppingcenter
# Saving message 4895 from modernshoppingcenter
# Saving message 4894 from modernshoppingcenter
# Saving message 4893 from modernshoppingcenter
# Saving message 4892 from modernshoppingcenter
# Saving message 4891 from modernshoppingcenter
# Saving message 4890 from modernshoppingcenter
# Saving message 4889 from modernshoppingcenter
# Saving message 4888 from modernshoppingcenter
# Saving message 4887 from modernshoppingcenter
# Saving message 4886 from modernshoppingcenter
# Saving message 4885 from modernshoppingcenter
# Saving message 4884 from modernshoppingcenter
# Saving message 4883 from modernshoppingcenter
# Saving message 4882 from modernshoppingcenter
# Saving message 4881 from modernshoppingcenter
# Saving message 4880 from modernshoppingcenter
# Saving message 4879 from modernshoppingcenter
# Saving message 4878 from modernshoppingcenter
# Saving message 4877 from modernshoppingcenter
# Saving message 4876 from modernshoppingcenter
# Saving message 4875 from modernshoppingcenter
# Saving message 4874 from modernshoppingcenter
# Saving message 4873 from modernshoppingcenter
# Saving message 4872 from modernshoppingcenter
# Saving message 4871 from modernshoppingcenter
# Saving message 4870 from modernshoppingcenter
# Saving message 4869 from modernshoppingcenter
# Saving message 4868 from modernshoppingcenter
# Saving message 4867 from modernshoppingcenter
# Saving message 4866 from modernshoppingcenter
# Saving message 4865 from modernshoppingcenter
# Saving message 4864 from modernshoppingcenter
# Saving message 4863 from modernshoppingcenter
# Saving message 4862 from modernshoppingcenter
# Saving message 4861 from modernshoppingcenter
# Saving message 4860 from modernshoppingcenter
# Saving message 4859 from modernshoppingcenter
# Saving message 4858 from modernshoppingcenter
# Saving message 4857 from modernshoppingcenter
# Saving message 4856 from modernshoppingcenter
# Saving message 4855 from modernshoppingcenter
# Saving message 4854 from modernshoppingcenter
# Saving message 4853 from modernshoppingcenter
# Saving message 4852 from modernshoppingcenter
# Saving message 4851 from modernshoppingcenter
# Saving message 4850 from modernshoppingcenter
# Saving message 4849 from modernshoppingcenter
# Saving message 4848 from modernshoppingcenter
# Saving message 4847 from modernshoppingcenter
# Saving message 4846 from modernshoppingcenter
# Saving message 4845 from modernshoppingcenter
# Saving message 4844 from modernshoppingcenter
# Saving message 4843 from modernshoppingcenter
# Saving message 4842 from modernshoppingcenter
# Saving message 4841 from modernshoppingcenter
# Saving message 4840 from modernshoppingcenter
# Saving message 4839 from modernshoppingcenter
# Saving message 4838 from modernshoppingcenter
# Saving message 4837 from modernshoppingcenter
# Saving message 4836 from modernshoppingcenter
# Saving message 4835 from modernshoppingcenter
# Saving message 4834 from modernshoppingcenter
# Saving message 4833 from modernshoppingcenter
# Saving message 4832 from modernshoppingcenter
# Saving message 4831 from modernshoppingcenter
# Saving message 4830 from modernshoppingcenter
# Saving message 4829 from modernshoppingcenter
# Saving message 4828 from modernshoppingcenter
# Saving message 4827 from modernshoppingcenter
# Saving message 4826 from modernshoppingcenter
# Saving message 4824 from modernshoppingcenter
# Saving message 4823 from modernshoppingcenter
# Saving message 4822 from modernshoppingcenter
# Saving message 4821 from modernshoppingcenter
# Saving message 4820 from modernshoppingcenter
# Saving message 4819 from modernshoppingcenter
# Saving message 4818 from modernshoppingcenter
# Saving message 4817 from modernshoppingcenter
# Saving message 4816 from modernshoppingcenter
# Saving message 4815 from modernshoppingcenter
# Saving message 4814 from modernshoppingcenter
# Saving message 4813 from modernshoppingcenter
# Saving message 4812 from modernshoppingcenter
# Saving message 4811 from modernshoppingcenter
# Saving message 4810 from modernshoppingcenter
# Saving message 4809 from modernshoppingcenter
# Saving message 4808 from modernshoppingcenter
# Saving message 4807 from modernshoppingcenter
# Saving message 4806 from modernshoppingcenter
# Saving message 4805 from modernshoppingcenter
# Saving message 4804 from modernshoppingcenter
# Saving message 4803 from modernshoppingcenter
# Saving message 4802 from modernshoppingcenter
# Saving message 4801 from modernshoppingcenter
# Saving message 4800 from modernshoppingcenter
# Saving message 4799 from modernshoppingcenter
# Saving message 4798 from modernshoppingcenter
# Saving message 4797 from modernshoppingcenter
# Saving message 4796 from modernshoppingcenter
# Saving message 4795 from modernshoppingcenter
# Saving message 4794 from modernshoppingcenter
# Saving message 4793 from modernshoppingcenter
# Saving message 4792 from modernshoppingcenter
# Saving message 4791 from modernshoppingcenter
# Saving message 4790 from modernshoppingcenter
# Saving message 4789 from modernshoppingcenter
# Saving message 4788 from modernshoppingcenter
# Saving message 4787 from modernshoppingcenter
# Saving message 4786 from modernshoppingcenter
# Saving message 4785 from modernshoppingcenter
# Saving message 4784 from modernshoppingcenter
# Saving message 4783 from modernshoppingcenter
# Saving message 4782 from modernshoppingcenter
# Saving message 4781 from modernshoppingcenter
# Saving message 4780 from modernshoppingcenter
# Saving message 4779 from modernshoppingcenter
# Saving message 4777 from modernshoppingcenter
# Saving message 4776 from modernshoppingcenter
# Saving message 4775 from modernshoppingcenter
# Saving message 4774 from modernshoppingcenter
# Saving message 4773 from modernshoppingcenter
# Saving message 4772 from modernshoppingcenter
# Saving message 4771 from modernshoppingcenter
# Saving message 4770 from modernshoppingcenter
# Saving message 4767 from modernshoppingcenter
# Saving message 4766 from modernshoppingcenter
# Saving message 4765 from modernshoppingcenter
# Saving message 4764 from modernshoppingcenter
# Saving message 4763 from modernshoppingcenter
# Saving message 4758 from modernshoppingcenter
# Saving message 4757 from modernshoppingcenter
# Saving message 4756 from modernshoppingcenter
# Saving message 4755 from modernshoppingcenter
# Saving message 4754 from modernshoppingcenter
# Saving message 4753 from modernshoppingcenter
# Saving message 4752 from modernshoppingcenter
# Saving message 4751 from modernshoppingcenter
# Saving message 4750 from modernshoppingcenter
# Saving message 4749 from modernshoppingcenter
# Saving message 4748 from modernshoppingcenter
# Saving message 4747 from modernshoppingcenter
# Saving message 4746 from modernshoppingcenter
# Saving message 4745 from modernshoppingcenter
# Saving message 4744 from modernshoppingcenter
# Saving message 4743 from modernshoppingcenter
# Saving message 4742 from modernshoppingcenter
# Saving message 4741 from modernshoppingcenter
# Saving message 4740 from modernshoppingcenter
# Saving message 4739 from modernshoppingcenter
# Saving message 4738 from modernshoppingcenter
# Saving message 4737 from modernshoppingcenter
# Saving message 4736 from modernshoppingcenter
# Saving message 4735 from modernshoppingcenter
# Saving message 4734 from modernshoppingcenter
# Saving message 4733 from modernshoppingcenter
# Saving message 4732 from modernshoppingcenter
# Saving message 4731 from modernshoppingcenter
# Saving message 4730 from modernshoppingcenter
# Saving message 4729 from modernshoppingcenter
# Saving message 4728 from modernshoppingcenter
# Saving message 4727 from modernshoppingcenter
# Saving message 4726 from modernshoppingcenter
# Saving message 4725 from modernshoppingcenter
# Saving message 4724 from modernshoppingcenter
# Saving message 4723 from modernshoppingcenter
# Saving message 4722 from modernshoppingcenter
# Saving message 4721 from modernshoppingcenter
# Saving message 4720 from modernshoppingcenter
# Saving message 4719 from modernshoppingcenter
# Saving message 4716 from modernshoppingcenter
# Saving message 4715 from modernshoppingcenter
# Saving message 4714 from modernshoppingcenter
# Saving message 4713 from modernshoppingcenter
# Saving message 4712 from modernshoppingcenter
# Saving message 4711 from modernshoppingcenter
# Saving message 4710 from modernshoppingcenter
# Saving message 4709 from modernshoppingcenter
# Saving message 4708 from modernshoppingcenter
# Saving message 4707 from modernshoppingcenter
# Saving message 4706 from modernshoppingcenter
# Saving message 4705 from modernshoppingcenter
# Saving message 4704 from modernshoppingcenter
# Saving message 4703 from modernshoppingcenter
# Saving message 4702 from modernshoppingcenter
# Saving message 4701 from modernshoppingcenter
# Saving message 4700 from modernshoppingcenter
# Saving message 4699 from modernshoppingcenter
# Saving message 4698 from modernshoppingcenter
# Saving message 4697 from modernshoppingcenter
# Saving message 4696 from modernshoppingcenter
# Saving message 4694 from modernshoppingcenter
# Saving message 4693 from modernshoppingcenter
# Saving message 4692 from modernshoppingcenter
# Saving message 4691 from modernshoppingcenter
# Saving message 4690 from modernshoppingcenter
# Saving message 4689 from modernshoppingcenter
# Saving message 4688 from modernshoppingcenter
# Saving message 4687 from modernshoppingcenter
# Saving message 4686 from modernshoppingcenter
# Saving message 4685 from modernshoppingcenter
# Saving message 4684 from modernshoppingcenter
# Saving message 4683 from modernshoppingcenter
# Saving message 4682 from modernshoppingcenter
# Saving message 4681 from modernshoppingcenter
# Saving message 4680 from modernshoppingcenter
# Saving message 4679 from modernshoppingcenter
# Saving message 4678 from modernshoppingcenter
# Saving message 4677 from modernshoppingcenter
# Saving message 4676 from modernshoppingcenter
# Saving message 4675 from modernshoppingcenter
# Saving message 4674 from modernshoppingcenter
# Saving message 4673 from modernshoppingcenter
# Saving message 4672 from modernshoppingcenter
# Saving message 4671 from modernshoppingcenter
# Saving message 4670 from modernshoppingcenter
# Saving message 4669 from modernshoppingcenter
# Saving message 4668 from modernshoppingcenter
# Saving message 4667 from modernshoppingcenter
# Saving message 4666 from modernshoppingcenter
# Saving message 4665 from modernshoppingcenter
# Saving message 4664 from modernshoppingcenter
# Saving message 4663 from modernshoppingcenter
# Saving message 4662 from modernshoppingcenter
# Saving message 4655 from modernshoppingcenter
# Saving message 4654 from modernshoppingcenter
# Saving message 4653 from modernshoppingcenter
# Saving message 4652 from modernshoppingcenter
# Saving message 4651 from modernshoppingcenter
# Saving message 4650 from modernshoppingcenter
# Saving message 4648 from modernshoppingcenter
# Saving message 4647 from modernshoppingcenter
# Saving message 4646 from modernshoppingcenter
# Saving message 4645 from modernshoppingcenter
# Saving message 4644 from modernshoppingcenter
# Saving message 4643 from modernshoppingcenter
# Saving message 4642 from modernshoppingcenter
# Saving message 4641 from modernshoppingcenter
# Saving message 4640 from modernshoppingcenter
# Saving message 4639 from modernshoppingcenter
# Saving message 4638 from modernshoppingcenter
# Saving message 4637 from modernshoppingcenter
# Saving message 4636 from modernshoppingcenter
# Saving message 4635 from modernshoppingcenter
# Saving message 4634 from modernshoppingcenter
# Saving message 4633 from modernshoppingcenter
# Saving message 4632 from modernshoppingcenter
# Saving message 4631 from modernshoppingcenter
# Saving message 4630 from modernshoppingcenter
# Saving message 4629 from modernshoppingcenter
# Saving message 4626 from modernshoppingcenter
# Saving message 4625 from modernshoppingcenter
# Saving message 4624 from modernshoppingcenter
# Saving message 4623 from modernshoppingcenter
# Saving message 4622 from modernshoppingcenter
# Saving message 4621 from modernshoppingcenter
# Saving message 4620 from modernshoppingcenter
# Saving message 4619 from modernshoppingcenter
# Saving message 4618 from modernshoppingcenter
# Saving message 4617 from modernshoppingcenter
# Saving message 4616 from modernshoppingcenter
# Saving message 4615 from modernshoppingcenter
# Saving message 4614 from modernshoppingcenter
# Saving message 4613 from modernshoppingcenter
# Saving message 4612 from modernshoppingcenter
# Saving message 4611 from modernshoppingcenter
# Saving message 4610 from modernshoppingcenter
# Saving message 4609 from modernshoppingcenter
# Saving message 4608 from modernshoppingcenter
# Saving message 4607 from modernshoppingcenter
# Saving message 4606 from modernshoppingcenter
# Saving message 4605 from modernshoppingcenter
# Saving message 4604 from modernshoppingcenter
# Saving message 4603 from modernshoppingcenter
# Saving message 4602 from modernshoppingcenter
# Saving message 4601 from modernshoppingcenter
# Saving message 4600 from modernshoppingcenter
# Saving message 4599 from modernshoppingcenter
# Saving message 4598 from modernshoppingcenter
# Saving message 4597 from modernshoppingcenter
# Saving message 4596 from modernshoppingcenter
# Saving message 4595 from modernshoppingcenter
# Saving message 4594 from modernshoppingcenter
# Saving message 4593 from modernshoppingcenter
# Saving message 4592 from modernshoppingcenter
# Saving message 4591 from modernshoppingcenter
# Saving message 4590 from modernshoppingcenter
# Saving message 4589 from modernshoppingcenter
# Saving message 4588 from modernshoppingcenter
# Saving message 4587 from modernshoppingcenter
# Saving message 4586 from modernshoppingcenter
# Saving message 4585 from modernshoppingcenter
# Saving message 4584 from modernshoppingcenter
# Saving message 4583 from modernshoppingcenter
# Saving message 4582 from modernshoppingcenter
# Saving message 4581 from modernshoppingcenter
# Saving message 4580 from modernshoppingcenter
# Saving message 4579 from modernshoppingcenter
# Saving message 4578 from modernshoppingcenter
# Saving message 4577 from modernshoppingcenter
# Saving message 4576 from modernshoppingcenter
# Saving message 4575 from modernshoppingcenter
# Saving message 4574 from modernshoppingcenter
# Saving message 4573 from modernshoppingcenter
# Saving message 4572 from modernshoppingcenter
# Saving message 4571 from modernshoppingcenter
# Saving message 4570 from modernshoppingcenter
# Saving message 4569 from modernshoppingcenter
# Saving message 4568 from modernshoppingcenter
# Saving message 4567 from modernshoppingcenter
# Saving message 4566 from modernshoppingcenter
# Saving message 4565 from modernshoppingcenter
# Saving message 4564 from modernshoppingcenter
# Saving message 4563 from modernshoppingcenter
# Saving message 4562 from modernshoppingcenter
# Saving message 4561 from modernshoppingcenter
# Saving message 4560 from modernshoppingcenter
# Saving message 4559 from modernshoppingcenter
# Saving message 4554 from modernshoppingcenter
# Saving message 4553 from modernshoppingcenter
# Saving message 4552 from modernshoppingcenter
# Saving message 4551 from modernshoppingcenter
# Saving message 4550 from modernshoppingcenter
# Saving message 4549 from modernshoppingcenter
# Saving message 4548 from modernshoppingcenter
# Saving message 4547 from modernshoppingcenter
# Saving message 4546 from modernshoppingcenter
# Saving message 4545 from modernshoppingcenter
# Saving message 4544 from modernshoppingcenter
# Saving message 4543 from modernshoppingcenter
# Saving message 4542 from modernshoppingcenter
# Saving message 4541 from modernshoppingcenter
# Saving message 4540 from modernshoppingcenter
# Saving message 4539 from modernshoppingcenter
# Saving message 4538 from modernshoppingcenter
# Saving message 4537 from modernshoppingcenter
# Saving message 4536 from modernshoppingcenter
# Saving message 4535 from modernshoppingcenter
# Saving message 4534 from modernshoppingcenter
# Saving message 4533 from modernshoppingcenter
# Saving message 4532 from modernshoppingcenter
# Saving message 4531 from modernshoppingcenter
# Saving message 4530 from modernshoppingcenter
# Saving message 4529 from modernshoppingcenter
# Saving message 4528 from modernshoppingcenter
# Saving message 4527 from modernshoppingcenter
# Saving message 4526 from modernshoppingcenter
# Saving message 4525 from modernshoppingcenter
# Saving message 4524 from modernshoppingcenter
# Saving message 4523 from modernshoppingcenter
# Saving message 4522 from modernshoppingcenter
# Saving message 4521 from modernshoppingcenter
# Saving message 4520 from modernshoppingcenter
# Saving message 4519 from modernshoppingcenter
# Saving message 4518 from modernshoppingcenter
# Saving message 4517 from modernshoppingcenter
# Saving message 4516 from modernshoppingcenter
# Saving message 4515 from modernshoppingcenter
# Saving message 4514 from modernshoppingcenter
# Saving message 4513 from modernshoppingcenter
# Saving message 4512 from modernshoppingcenter
# Saving message 4511 from modernshoppingcenter
# Saving message 4510 from modernshoppingcenter
# Saving message 4509 from modernshoppingcenter
# Saving message 4508 from modernshoppingcenter
# Saving message 4507 from modernshoppingcenter
# Saving message 4506 from modernshoppingcenter
# Saving message 4505 from modernshoppingcenter
# Saving message 4504 from modernshoppingcenter
# Saving message 4503 from modernshoppingcenter
# Saving message 4502 from modernshoppingcenter
# Saving message 4501 from modernshoppingcenter
# Saving message 4500 from modernshoppingcenter
# Saving message 4499 from modernshoppingcenter
# Saving message 4498 from modernshoppingcenter
# Saving message 4497 from modernshoppingcenter
# Saving message 4496 from modernshoppingcenter
# Saving message 4495 from modernshoppingcenter
# Saving message 4493 from modernshoppingcenter
# Saving message 4492 from modernshoppingcenter
# Saving message 4491 from modernshoppingcenter
# Saving message 4490 from modernshoppingcenter
# Saving message 4489 from modernshoppingcenter
# Saving message 4488 from modernshoppingcenter
# Saving message 4487 from modernshoppingcenter
# Saving message 4486 from modernshoppingcenter
# Saving message 4485 from modernshoppingcenter
# Saving message 4484 from modernshoppingcenter
# Saving message 4483 from modernshoppingcenter
# Saving message 4482 from modernshoppingcenter
# Saving message 4481 from modernshoppingcenter
# Saving message 4480 from modernshoppingcenter
# Saving message 4479 from modernshoppingcenter
# Saving message 4478 from modernshoppingcenter
# Saving message 4477 from modernshoppingcenter
# Saving message 4476 from modernshoppingcenter
# Saving message 4475 from modernshoppingcenter
# Saving message 4474 from modernshoppingcenter
# Saving message 4473 from modernshoppingcenter
# Saving message 4472 from modernshoppingcenter
# Saving message 4471 from modernshoppingcenter
# Saving message 4470 from modernshoppingcenter
# Saving message 4469 from modernshoppingcenter
# Saving message 4468 from modernshoppingcenter
# Saving message 4467 from modernshoppingcenter
# Saving message 4466 from modernshoppingcenter
# Saving message 4465 from modernshoppingcenter
# Saving message 4464 from modernshoppingcenter
# Saving message 4463 from modernshoppingcenter
# Saving message 4462 from modernshoppingcenter
# Saving message 4461 from modernshoppingcenter
# Saving message 4460 from modernshoppingcenter
# Saving message 4459 from modernshoppingcenter
# Saving message 4458 from modernshoppingcenter
# Saving message 4457 from modernshoppingcenter
# Saving message 4456 from modernshoppingcenter
# Saving message 4452 from modernshoppingcenter
# Saving message 4451 from modernshoppingcenter
# Saving message 4450 from modernshoppingcenter
# Saving message 4449 from modernshoppingcenter
# Saving message 4448 from modernshoppingcenter
# Saving message 4447 from modernshoppingcenter
# Saving message 4446 from modernshoppingcenter
# Saving message 4445 from modernshoppingcenter
# Saving message 4444 from modernshoppingcenter
# Saving message 4443 from modernshoppingcenter
# Saving message 4442 from modernshoppingcenter
# Saving message 4441 from modernshoppingcenter
# Saving message 4437 from modernshoppingcenter
# Saving message 4436 from modernshoppingcenter
# Saving message 4435 from modernshoppingcenter
# Saving message 4434 from modernshoppingcenter
# Saving message 4433 from modernshoppingcenter
# Saving message 4432 from modernshoppingcenter
# Saving message 4431 from modernshoppingcenter
# Saving message 4430 from modernshoppingcenter
# Saving message 4429 from modernshoppingcenter
# Saving message 4428 from modernshoppingcenter
# Saving message 4427 from modernshoppingcenter
# Saving message 4426 from modernshoppingcenter
# Saving message 4425 from modernshoppingcenter
# Saving message 4424 from modernshoppingcenter
# Saving message 4423 from modernshoppingcenter
# Saving message 4422 from modernshoppingcenter
# Saving message 4421 from modernshoppingcenter
# Saving message 4420 from modernshoppingcenter
# Saving message 4419 from modernshoppingcenter
# Saving message 4418 from modernshoppingcenter
# Saving message 4417 from modernshoppingcenter
# Saving message 4416 from modernshoppingcenter
# Saving message 4415 from modernshoppingcenter
# Saving message 4414 from modernshoppingcenter
# Saving message 4413 from modernshoppingcenter
# Saving message 4412 from modernshoppingcenter
# Saving message 4411 from modernshoppingcenter
# Saving message 4410 from modernshoppingcenter
# Saving message 4409 from modernshoppingcenter
# Saving message 4408 from modernshoppingcenter
# Saving message 4407 from modernshoppingcenter
# Saving message 4406 from modernshoppingcenter
# Saving message 4405 from modernshoppingcenter
# Saving message 4404 from modernshoppingcenter
# Saving message 4403 from modernshoppingcenter
# Saving message 4402 from modernshoppingcenter
# Saving message 4401 from modernshoppingcenter
# Saving message 4400 from modernshoppingcenter
# Saving message 4399 from modernshoppingcenter
# Saving message 4398 from modernshoppingcenter
# Saving message 4397 from modernshoppingcenter
# Saving message 4396 from modernshoppingcenter
# Saving message 4391 from modernshoppingcenter
# Saving message 4390 from modernshoppingcenter
# Saving message 4388 from modernshoppingcenter
# Saving message 4387 from modernshoppingcenter
# Saving message 4386 from modernshoppingcenter
# Saving message 4385 from modernshoppingcenter
# Saving message 4384 from modernshoppingcenter
# Saving message 4383 from modernshoppingcenter
# Saving message 4382 from modernshoppingcenter
# Saving message 4381 from modernshoppingcenter
# Saving message 4380 from modernshoppingcenter
# Saving message 4379 from modernshoppingcenter
# Saving message 4378 from modernshoppingcenter
# Saving message 4377 from modernshoppingcenter
# Saving message 4376 from modernshoppingcenter
# Saving message 4375 from modernshoppingcenter
# Saving message 4374 from modernshoppingcenter
# Saving message 4373 from modernshoppingcenter
# Saving message 4372 from modernshoppingcenter
# Saving message 4371 from modernshoppingcenter
# Saving message 4370 from modernshoppingcenter
# Saving message 4369 from modernshoppingcenter
# Saving message 4368 from modernshoppingcenter
# Saving message 4367 from modernshoppingcenter
# Saving message 4366 from modernshoppingcenter
# Saving message 4365 from modernshoppingcenter
# Saving message 4364 from modernshoppingcenter
# Saving message 4363 from modernshoppingcenter
# Saving message 4362 from modernshoppingcenter
# Saving message 4361 from modernshoppingcenter
# Saving message 4360 from modernshoppingcenter
# Saving message 4359 from modernshoppingcenter
# Saving message 4358 from modernshoppingcenter
# Saving message 4357 from modernshoppingcenter
# Saving message 4356 from modernshoppingcenter
# Saving message 4355 from modernshoppingcenter
# Saving message 4354 from modernshoppingcenter
# Saving message 4353 from modernshoppingcenter
# Saving message 4352 from modernshoppingcenter
# Saving message 4351 from modernshoppingcenter
# Saving message 4350 from modernshoppingcenter
# Saving message 4349 from modernshoppingcenter
# Saving message 4348 from modernshoppingcenter
# Saving message 4347 from modernshoppingcenter
# Saving message 4346 from modernshoppingcenter
# Saving message 4345 from modernshoppingcenter
# Saving message 4344 from modernshoppingcenter
# Saving message 4343 from modernshoppingcenter
# Saving message 4342 from modernshoppingcenter
# Saving message 4341 from modernshoppingcenter
# Saving message 4340 from modernshoppingcenter
# Saving message 4339 from modernshoppingcenter
# Saving message 4338 from modernshoppingcenter
# Saving message 4337 from modernshoppingcenter
# Saving message 4336 from modernshoppingcenter
# Saving message 4335 from modernshoppingcenter
# Saving message 4334 from modernshoppingcenter
# Saving message 4333 from modernshoppingcenter
# Saving message 4332 from modernshoppingcenter
# Saving message 4327 from modernshoppingcenter
# Saving message 4325 from modernshoppingcenter
# Saving message 4324 from modernshoppingcenter
# Saving message 4323 from modernshoppingcenter
# Saving message 4322 from modernshoppingcenter
# Saving message 4321 from modernshoppingcenter
# Saving message 4320 from modernshoppingcenter
# Saving message 4319 from modernshoppingcenter
# Saving message 4318 from modernshoppingcenter
# Saving message 4317 from modernshoppingcenter
# Saving message 4316 from modernshoppingcenter
# Saving message 4315 from modernshoppingcenter
# Saving message 4314 from modernshoppingcenter
# Saving message 4313 from modernshoppingcenter
# Saving message 4312 from modernshoppingcenter
# Saving message 4311 from modernshoppingcenter
# Saving message 4310 from modernshoppingcenter
# Saving message 4309 from modernshoppingcenter
# Saving message 4308 from modernshoppingcenter
# Saving message 4307 from modernshoppingcenter
# Saving message 4306 from modernshoppingcenter
# Saving message 4305 from modernshoppingcenter
# Saving message 4304 from modernshoppingcenter
# Saving message 4303 from modernshoppingcenter
# Saving message 4301 from modernshoppingcenter
# Saving message 4300 from modernshoppingcenter
# Saving message 4299 from modernshoppingcenter
# Saving message 4298 from modernshoppingcenter
# Saving message 4297 from modernshoppingcenter
# Saving message 4296 from modernshoppingcenter
# Saving message 4295 from modernshoppingcenter
# Saving message 4294 from modernshoppingcenter
# Saving message 4293 from modernshoppingcenter
# Saving message 4292 from modernshoppingcenter
# Saving message 4291 from modernshoppingcenter
# Saving message 4290 from modernshoppingcenter
# Saving message 4289 from modernshoppingcenter
# Saving message 4239 from modernshoppingcenter
# Saving message 4238 from modernshoppingcenter
# Saving message 4237 from modernshoppingcenter
# Saving message 4236 from modernshoppingcenter
# Saving message 4235 from modernshoppingcenter
# Saving message 4234 from modernshoppingcenter
# Saving message 4233 from modernshoppingcenter
# Saving message 4232 from modernshoppingcenter
# Saving message 4231 from modernshoppingcenter
# Saving message 4230 from modernshoppingcenter
# Saving message 4229 from modernshoppingcenter
# Saving message 4228 from modernshoppingcenter
# Saving message 4227 from modernshoppingcenter
# Saving message 4226 from modernshoppingcenter
# Saving message 4225 from modernshoppingcenter
# Saving message 4224 from modernshoppingcenter
# Saving message 4223 from modernshoppingcenter
# Saving message 4222 from modernshoppingcenter
# Saving message 4221 from modernshoppingcenter
# Saving message 4220 from modernshoppingcenter
# Saving message 4219 from modernshoppingcenter
# Saving message 4218 from modernshoppingcenter
# Saving message 4217 from modernshoppingcenter
# ...
# Saving message 423 from modernshoppingcenter
# Saving message 422 from modernshoppingcenter
# Saving message 421 from modernshoppingcenter
# Saving message 420 from modernshoppingcenter
# Saving message 419 from modernshoppingcenter
# Saving message 418 from modernshoppingcenter
# Saving message 417 from modernshoppingcenter
# Saving message 416 from modernshoppingcenter
# Saving message 415 from modernshoppingcenter
# Saving message 414 from modernshoppingcenter
# Saving message 413 from modernshoppingcenter
# Saving message 412 from modernshoppingcenter
# Saving message 411 from modernshoppingcenter
# Saving message 410 from modernshoppingcenter
# Saving message 409 from modernshoppingcenter
# Saving message 408 from modernshoppingcenter
# Saving message 407 from modernshoppingcenter
# Saving message 406 from modernshoppingcenter
# Saving message 405 from modernshoppingcenter
# Saving message 404 from modernshoppingcenter
# Saving message 403 from modernshoppingcenter
# Saving message 402 from modernshoppingcenter
# Saving message 401 from modernshoppingcenter
# Saving message 400 from modernshoppingcenter
# Saving message 399 from modernshoppingcenter
# Saving message 398 from modernshoppingcenter
# Saving message 397 from modernshoppingcenter
# Saving message 396 from modernshoppingcenter
# Saving message 395 from modernshoppingcenter
# Saving message 394 from modernshoppingcenter
# Saving message 393 from modernshoppingcenter
# Saving message 392 from modernshoppingcenter
# Saving message 391 from modernshoppingcenter
# Saving message 390 from modernshoppingcenter
# Saving message 389 from modernshoppingcenter
# Saving message 388 from modernshoppingcenter
# Saving message 387 from modernshoppingcenter
# Saving message 386 from modernshoppingcenter
# Saving message 385 from modernshoppingcenter
# Saving message 384 from modernshoppingcenter
# Saving message 383 from modernshoppingcenter
# Saving message 382 from modernshoppingcenter
# Saving message 381 from modernshoppingcenter
# Saving message 380 from modernshoppingcenter
# Saving message 379 from modernshoppingcenter
# Saving message 378 from modernshoppingcenter
# Saving message 377 from modernshoppingcenter
# Saving message 376 from modernshoppingcenter
# Saving message 375 from modernshoppingcenter
# Saving message 374 from modernshoppingcenter
# Saving message 373 from modernshoppingcenter
# Saving message 372 from modernshoppingcenter
# Saving message 371 from modernshoppingcenter
# Saving message 370 from modernshoppingcenter
# Saving message 369 from modernshoppingcenter
# Saving message 368 from modernshoppingcenter
# Saving message 367 from modernshoppingcenter
# Saving message 366 from modernshoppingcenter
# Saving message 365 from modernshoppingcenter
# Saving message 364 from modernshoppingcenter
# Saving message 363 from modernshoppingcenter
# Saving message 362 from modernshoppingcenter
# Saving message 361 from modernshoppingcenter
# Saving message 360 from modernshoppingcenter
# Saving message 359 from modernshoppingcenter
# Saving message 358 from modernshoppingcenter
# Saving message 357 from modernshoppingcenter
# Saving message 356 from modernshoppingcenter
# Saving message 355 from modernshoppingcenter
# Saving message 354 from modernshoppingcenter
# Saving message 353 from modernshoppingcenter
# Saving message 352 from modernshoppingcenter
# Saving message 351 from modernshoppingcenter
# Saving message 350 from modernshoppingcenter
# Saving message 349 from modernshoppingcenter
# Saving message 348 from modernshoppingcenter
# Saving message 347 from modernshoppingcenter
# Saving message 346 from modernshoppingcenter
# Saving message 345 from modernshoppingcenter
# Saving message 344 from modernshoppingcenter
# Saving message 343 from modernshoppingcenter
# Saving message 342 from modernshoppingcenter
# Saving message 341 from modernshoppingcenter
# Saving message 340 from modernshoppingcenter
# Saving message 339 from modernshoppingcenter
# Saving message 338 from modernshoppingcenter
# Saving message 337 from modernshoppingcenter
# Saving message 336 from modernshoppingcenter
# Saving message 335 from modernshoppingcenter
# Saving message 334 from modernshoppingcenter
# Saving message 333 from modernshoppingcenter
# Saving message 332 from modernshoppingcenter
# Saving message 331 from modernshoppingcenter
# Saving message 330 from modernshoppingcenter
# Saving message 329 from modernshoppingcenter
# Saving message 328 from modernshoppingcenter
# Saving message 327 from modernshoppingcenter
# Saving message 326 from modernshoppingcenter
# Saving message 325 from modernshoppingcenter
# Saving message 324 from modernshoppingcenter
# Saving message 323 from modernshoppingcenter
# Saving message 322 from modernshoppingcenter
# Saving message 321 from modernshoppingcenter
# Saving message 320 from modernshoppingcenter
# Saving message 319 from modernshoppingcenter
# Saving message 318 from modernshoppingcenter
# Saving message 317 from modernshoppingcenter
# Saving message 316 from modernshoppingcenter
# Saving message 315 from modernshoppingcenter
# Saving message 314 from modernshoppingcenter
# Saving message 313 from modernshoppingcenter
# Saving message 312 from modernshoppingcenter
# Saving message 311 from modernshoppingcenter
# Saving message 310 from modernshoppingcenter
# Saving message 309 from modernshoppingcenter
# Saving message 308 from modernshoppingcenter
# Saving message 307 from modernshoppingcenter
# Saving message 306 from modernshoppingcenter
# Saving message 296 from modernshoppingcenter
# Saving message 295 from modernshoppingcenter
# Saving message 294 from modernshoppingcenter
# Saving message 293 from modernshoppingcenter
# Saving message 291 from modernshoppingcenter
# Saving message 290 from modernshoppingcenter
# Saving message 289 from modernshoppingcenter
# Saving message 288 from modernshoppingcenter
# Saving message 287 from modernshoppingcenter
# Saving message 286 from modernshoppingcenter
# Saving message 285 from modernshoppingcenter
# Saving message 284 from modernshoppingcenter
# Saving message 283 from modernshoppingcenter
# Saving message 282 from modernshoppingcenter
# Saving message 281 from modernshoppingcenter
# Saving message 280 from modernshoppingcenter
# Saving message 279 from modernshoppingcenter
# Saving message 278 from modernshoppingcenter
# Saving message 277 from modernshoppingcenter
# Saving message 276 from modernshoppingcenter
# Saving message 275 from modernshoppingcenter
# Saving message 274 from modernshoppingcenter
# Saving message 272 from modernshoppingcenter
# Saving message 271 from modernshoppingcenter
# Saving message 270 from modernshoppingcenter
# Saving message 269 from modernshoppingcenter
# Saving message 268 from modernshoppingcenter
# Saving message 267 from modernshoppingcenter
# Saving message 266 from modernshoppingcenter
# Saving message 265 from modernshoppingcenter
# Saving message 264 from modernshoppingcenter
# Saving message 263 from modernshoppingcenter
# Saving message 262 from modernshoppingcenter
# Saving message 261 from modernshoppingcenter
# Saving message 260 from modernshoppingcenter
# Saving message 259 from modernshoppingcenter
# Saving message 258 from modernshoppingcenter
# Saving message 255 from modernshoppingcenter
# Saving message 254 from modernshoppingcenter
# Saving message 253 from modernshoppingcenter
# Saving message 252 from modernshoppingcenter
# Saving message 251 from modernshoppingcenter
# Saving message 250 from modernshoppingcenter
# Saving message 249 from modernshoppingcenter
# Saving message 248 from modernshoppingcenter
# Saving message 247 from modernshoppingcenter
# Saving message 246 from modernshoppingcenter
# Saving message 245 from modernshoppingcenter
# Saving message 244 from modernshoppingcenter
# Saving message 243 from modernshoppingcenter
# Saving message 242 from modernshoppingcenter
# Saving message 241 from modernshoppingcenter
# Saving message 240 from modernshoppingcenter
# Saving message 239 from modernshoppingcenter
# Saving message 238 from modernshoppingcenter
# Saving message 237 from modernshoppingcenter
# Saving message 236 from modernshoppingcenter
# Saving message 235 from modernshoppingcenter
# Saving message 234 from modernshoppingcenter
# Saving message 233 from modernshoppingcenter
# Saving message 232 from modernshoppingcenter
# Saving message 231 from modernshoppingcenter
# Saving message 230 from modernshoppingcenter
# Saving message 229 from modernshoppingcenter
# Saving message 228 from modernshoppingcenter
# Saving message 227 from modernshoppingcenter
# Saving message 226 from modernshoppingcenter
# Saving message 225 from modernshoppingcenter
# Saving message 224 from modernshoppingcenter
# Saving message 223 from modernshoppingcenter
# Saving message 222 from modernshoppingcenter
# Saving message 221 from modernshoppingcenter
# Saving message 220 from modernshoppingcenter
# Saving message 219 from modernshoppingcenter
# Saving message 218 from modernshoppingcenter
# Saving message 217 from modernshoppingcenter
# Saving message 216 from modernshoppingcenter
# Saving message 215 from modernshoppingcenter
# Saving message 214 from modernshoppingcenter
# Saving message 213 from modernshoppingcenter
# Saving message 212 from modernshoppingcenter
# Saving message 211 from modernshoppingcenter
# Saving message 210 from modernshoppingcenter
# Saving message 209 from modernshoppingcenter
# Saving message 208 from modernshoppingcenter
# Saving message 207 from modernshoppingcenter
# Saving message 206 from modernshoppingcenter
# Saving message 205 from modernshoppingcenter
# Saving message 204 from modernshoppingcenter
# Saving message 203 from modernshoppingcenter
# Saving message 202 from modernshoppingcenter
# Saving message 201 from modernshoppingcenter
# Saving message 200 from modernshoppingcenter
# Saving message 199 from modernshoppingcenter
# Saving message 198 from modernshoppingcenter
# Saving message 197 from modernshoppingcenter
# Saving message 196 from modernshoppingcenter
# Saving message 186 from modernshoppingcenter
# Saving message 185 from modernshoppingcenter
# Saving message 184 from modernshoppingcenter
# Saving message 183 from modernshoppingcenter
# Saving message 182 from modernshoppingcenter
# Saving message 181 from modernshoppingcenter
# Saving message 180 from modernshoppingcenter
# Saving message 179 from modernshoppingcenter
# Saving message 178 from modernshoppingcenter
# Saving message 177 from modernshoppingcenter
# Saving message 176 from modernshoppingcenter
# Saving message 175 from modernshoppingcenter
# Saving message 174 from modernshoppingcenter
# Saving message 173 from modernshoppingcenter
# Saving message 172 from modernshoppingcenter
# Saving message 171 from modernshoppingcenter
# Saving message 170 from modernshoppingcenter
# Saving message 169 from modernshoppingcenter
# Saving message 168 from modernshoppingcenter
# Saving message 159 from modernshoppingcenter
# Saving message 158 from modernshoppingcenter
# Saving message 157 from modernshoppingcenter
# Saving message 156 from modernshoppingcenter
# Saving message 155 from modernshoppingcenter
# Saving message 154 from modernshoppingcenter
# Saving message 153 from modernshoppingcenter
# Saving message 152 from modernshoppingcenter
# Saving message 151 from modernshoppingcenter
# Saving message 150 from modernshoppingcenter
# Saving message 149 from modernshoppingcenter
# Saving message 148 from modernshoppingcenter
# Saving message 147 from modernshoppingcenter
# Saving message 146 from modernshoppingcenter
# Saving message 144 from modernshoppingcenter
# Saving message 143 from modernshoppingcenter
# Saving message 142 from modernshoppingcenter
# Saving message 140 from modernshoppingcenter
# Saving message 136 from modernshoppingcenter
# Saving message 135 from modernshoppingcenter
# Saving message 133 from modernshoppingcenter
# Saving message 132 from modernshoppingcenter
# Saving message 131 from modernshoppingcenter
# Saving message 130 from modernshoppingcenter
# Saving message 129 from modernshoppingcenter
# Saving message 128 from modernshoppingcenter
# Saving message 124 from modernshoppingcenter
# Saving message 123 from modernshoppingcenter
# Saving message 122 from modernshoppingcenter
# Saving message 121 from modernshoppingcenter
# Saving message 117 from modernshoppingcenter
# Saving message 116 from modernshoppingcenter
# Saving message 115 from modernshoppingcenter
# Saving message 114 from modernshoppingcenter
# Saving message 113 from modernshoppingcenter
# Saving message 112 from modernshoppingcenter
# Saving message 111 from modernshoppingcenter
# Saving message 110 from modernshoppingcenter
# Saving message 109 from modernshoppingcenter
# Saving message 106 from modernshoppingcenter
# Saving message 105 from modernshoppingcenter
# Saving message 104 from modernshoppingcenter
# Saving message 103 from modernshoppingcenter
# Saving message 102 from modernshoppingcenter
# Saving message 100 from modernshoppingcenter
# Saving message 99 from modernshoppingcenter
# Saving message 98 from modernshoppingcenter
# Saving message 97 from modernshoppingcenter
# Saving message 96 from modernshoppingcenter
# Saving message 95 from modernshoppingcenter
# Saving message 94 from modernshoppingcenter
# Saving message 93 from modernshoppingcenter
# Saving message 92 from modernshoppingcenter
# Saving message 91 from modernshoppingcenter
# Saving message 90 from modernshoppingcenter
# Saving message 89 from modernshoppingcenter
# Saving message 84 from modernshoppingcenter
# Saving message 83 from modernshoppingcenter
# Saving message 82 from modernshoppingcenter
# Saving message 80 from modernshoppingcenter
# Saving message 79 from modernshoppingcenter
# Saving message 78 from modernshoppingcenter
# Saving message 77 from modernshoppingcenter
# Saving message 76 from modernshoppingcenter
# Saving message 75 from modernshoppingcenter
# Saving message 74 from modernshoppingcenter
# Saving message 73 from modernshoppingcenter
# Saving message 72 from modernshoppingcenter
# Saving message 71 from modernshoppingcenter
# Saving message 68 from modernshoppingcenter
# Saving message 67 from modernshoppingcenter
# Saving message 65 from modernshoppingcenter
# Saving message 64 from modernshoppingcenter
# Saving message 63 from modernshoppingcenter
# Saving message 62 from modernshoppingcenter
# Saving message 61 from modernshoppingcenter
# Saving message 60 from modernshoppingcenter
# Saving message 59 from modernshoppingcenter
# Saving message 58 from modernshoppingcenter
# Saving message 57 from modernshoppingcenter
# Saving message 54 from modernshoppingcenter
# Saving message 53 from modernshoppingcenter
# Saving message 51 from modernshoppingcenter
# Saving message 50 from modernshoppingcenter
# Saving message 49 from modernshoppingcenter
# Saving message 48 from modernshoppingcenter
# Saving message 47 from modernshoppingcenter
# Saving message 46 from modernshoppingcenter
# Saving message 45 from modernshoppingcenter
# Saving message 44 from modernshoppingcenter
# Saving message 43 from modernshoppingcenter
# Saving message 42 from modernshoppingcenter
# Saving message 41 from modernshoppingcenter
# Saving message 40 from modernshoppingcenter
# Saving message 37 from modernshoppingcenter
# Saving message 36 from modernshoppingcenter
# Saving message 35 from modernshoppingcenter
# Saving message 34 from modernshoppingcenter
# Saving message 33 from modernshoppingcenter
# Saving message 32 from modernshoppingcenter
# Saving message 31 from modernshoppingcenter
# Saving message 30 from modernshoppingcenter
# Saving message 28 from modernshoppingcenter
# Saving message 25 from modernshoppingcenter
# Saving message 24 from modernshoppingcenter
# Saving message 23 from modernshoppingcenter
# Saving message 22 from modernshoppingcenter
# Saving message 18 from modernshoppingcenter
# Saving message 17 from modernshoppingcenter
# Saving message 16 from modernshoppingcenter
# Saving message 15 from modernshoppingcenter
# Saving message 14 from modernshoppingcenter
# Saving message 13 from modernshoppingcenter
# Saving message 11 from modernshoppingcenter
# Saving message 10 from modernshoppingcenter
# Saving message 9 from modernshoppingcenter
# Saving message 8 from modernshoppingcenter
# Saving message 6 from modernshoppingcenter
# Saving message 5 from modernshoppingcenter
# Saving message 4 from modernshoppingcenter
# Saving message 1 from modernshoppingcenter
# Finished fetching messages and saved to ../data/telegram_messages.csv.
# Disconnected from Telegram

# %%
# Read downloded CSV data into dataFrame
telegram_data = pd.read_csv('../data/telegram_messages.csv')

# %% [markdown]
# ### Text Preprocessing

# %% [markdown]
# ##### Initialization: Create an instance of the AmharicTextPreprocessor class.

# %%
text_processor = AmharicTextPreprocessor()

# %%
# Apply preprocessing to 'Message' column
telegram_data['Preprocessed_Message'] = telegram_data['Message'].apply(text_processor.preprocess_text)

# Display the preprocessed data
telegram_data[['Message', 'Preprocessed_Message']]
# Out:
#                                                 Message  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3     **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**...
# 4                                                   NaN
# ...                                                 ...
# 4788  እጅግ በጣም ኳሊቲ የቡና መፍጫ\nየማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ  ያ...
# 4789  ኳሊቲ የቡና ስኒ ከነማስቀመጫው፣ከነመስቀያው\nበ950ብር \nአድራሻ ጉርድ...
# 4790  ተንጠልጣይ የሻይ፣የቡና እና የወተት ኮምፕሌት\nበ600ብር ብቻ\nአድራሻ ...
# 4791                                                NaN
# 4792                                                NaN
#
#                                    Preprocessed_Message
# 0
# 1
# 2
# 3     ቴሌግራም በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን የፍራፍሬ መጭመቂያ ብርቱካን ...
# 4
# ...                                                 ...
# 4788  እጅግ በጣም ኳሊቲ የቡና መፍጫ የማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ ያለው...
# 4789  ኳሊቲ የቡና ስኒ ከነማስቀመጫውከነመስቀያው በ950ብር አድራሻ ጉርድ ሾላ ...
# 4790  ተንጠልጣይ የሻይየቡና እና የወተት ኮምፕሌት በ600ብር ብቻ አድራሻ ጉርድ...
# 4791
# 4792
#
# [4793 rows x 2 columns]

# %%
# filter Not null values from message columns
telegram_data = telegram_data[telegram_data['Preprocessed_Message']!=("")]
telegram_data
# Out:
#                    channel  message_id                       date  \
# 3     modernshoppingcenter        5379  2025-01-17T12:26:50+00:00
# 8     modernshoppingcenter        5374  2025-01-17T07:49:42+00:00
# 12    modernshoppingcenter        5370  2025-01-16T15:18:29+00:00
# 16    modernshoppingcenter        5366  2025-01-16T07:38:01+00:00
# 17    modernshoppingcenter        5365  2025-01-15T08:21:58+00:00
# ...                    ...         ...                        ...
# 4785  modernshoppingcenter          11  2022-02-18T17:43:44+00:00
# 4787  modernshoppingcenter           9  2022-02-18T17:43:20+00:00
# 4788  modernshoppingcenter           8  2022-02-18T17:42:21+00:00
# 4789  modernshoppingcenter           6  2022-02-18T17:40:19+00:00
# 4790  modernshoppingcenter           5  2022-02-18T17:37:43+00:00
#
#              sender                                            Message  \
# 3    -1001649695480  **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**...
# 8    -1001649695480  **ቴሌግራም👉t.me/modernshoppingcenter****\n     "በ...
# 12   -1001649695480  **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**...
# 16   -1001649695480  **ቴሌግራም****🫐**** **t.me/modernshoppingcenter**...
# 17   -1001649695480  **🔥**** ተጀመረ ****💡****ተጀመረ****💡**** ተጀመረ ****🔥...
# ...             ...                                                ...
# 4785 -1001649695480  የተለያየ ማራኪ ቅርጽ ያላችው የቡና ሲኒዎች\nበ600ብር ብቻ\nአድራሻ ጉ...
# 4787 -1001649695480  ለጨው፣ለስኳር ማቅረቢያ\nከንፁህ ሴራሚክ የተሰራ\nበ400ብር ብቻ።\nአድ...
# 4788 -1001649695480  እጅግ በጣም ኳሊቲ የቡና መፍጫ\nየማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ  ያ...
# 4789 -1001649695480  ኳሊቲ የቡና ስኒ ከነማስቀመጫው፣ከነመስቀያው\nበ950ብር \nአድራሻ ጉርድ...
# 4790 -1001649695480  ተንጠልጣይ የሻይ፣የቡና እና የወተት ኮምፕሌት\nበ600ብር ብቻ\nአድራሻ ...
#
#                      media                               Preprocessed_Message
# 3        MessageMediaPhoto  ቴሌግራም በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን የፍራፍሬ መጭመቂያ ብርቱካን ...
# 8        MessageMediaPhoto  ቴሌግራም በአዲስ ነገር ሁሌም ቀዳሚዏች ነን አዲስ የጤና መጠበቂያ ማሽን ...
# 12    MessageMediaDocument  ቴሌግራም በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን የልጆች ምግብ መስሪያ በከፍተ...
# 16       MessageMediaPhoto  ቴሌግራም በአዲስ ነገረ ሁሌም ቀዳሚዏች ነን ️ የፍራፍሬ አና የፓስታ ማጥ...
# 17       MessageMediaPhoto  ተጀመረ ተጀመረ ተጀመረ ልዩ እዉነተኛ የበዓል ቅናሽ ከታህሳስ 21 እስከ ...
# ...                    ...                                                ...
# 4785     MessageMediaPhoto  የተለያየ ማራኪ ቅርጽ ያላችው የቡና ሲኒዎች በ600ብር ብቻ አድራሻ ጉርድ...
# 4787     MessageMediaPhoto  ለጨውለስኳር ማቅረቢያ ከንፁህ ሴራሚክ የተሰራ በ400ብር ብቻ አድራሻ ጉር...
# 4788     MessageMediaPhoto  እጅግ በጣም ኳሊቲ የቡና መፍጫ የማድቀቅ ደረጃውን በራሱ መቆጣጠሪያ ያለው...
# 4789     MessageMediaPhoto  ኳሊቲ የቡና ስኒ ከነማስቀመጫውከነመስቀያው በ950ብር አድራሻ ጉርድ ሾላ ...
# 4790     MessageMediaPhoto  ተንጠልጣይ የሻይየቡና እና የወተት ኮምፕሌት በ600ብር ብቻ አድራሻ ጉርድ...
#
# [1736 rows x 7 columns]

# %% [markdown]
# ### Task 2 : Label a Subset of Dataset in CoNLL

# %%
# Import EntityLabeler class
from scripts.data_labeling import EntityLabeler
# 1. Initialize the entity labeler
entity_labeler = EntityLabeler()

# 2. Generate CoNLL formatted string for messages from 0 to 50 (or any range dynamically)
start_message = 0
batch_size = 50  # You can adjust this to 50, 100, or any other size you want
conll_output = entity_labeler.create_conll_format(telegram_data, start_message, batch_size)


# # Generate for the next batch, for example 51-100
# start_message = 51
# batch_size = 50
# conll_output = entity_labeler.create_conll_format(telegram_data, start_message, batch_size)
# entity_labeler.save_conll_to_file(conll_output, f'telegram_data_conll_format_{start_message}_{start_message + batch_size}.txt')

# %% [markdown]
# ### Save the data in CoNLL format

# %%
# Save the generated output to a text file
entity_labeler.save_conll_to_file(conll_output, f'telegram_data_conll_format_{start_message}_{start_message + batch_size}.txt')
# Out:
# CoNLL format data has been saved to 'telegram_data_conll_format_0_50.txt'
